# %% [markdown]
# # Big O

# %% [markdown]
# ### Big O asymptotic analysis
# ### its a performance parameter
#
# Big Os
#
# #### O(1) Constant – no loops
# #### O(log N) Logarithmic – usually searching algorithms have log n if they are sorted (Binary Search)
# #### O(n) Linear – for loops, while loops through n items
# #### O(n log(n)) Log Linear – usually sorting operations
# #### O(n^2) Quadratic – every element in a collection needs to be compared to ever other element. Two nested loops
# #### O(2^n) Exponential – recursive algorithms that solves a problem of size N
# #### O(n!) Factorial – you are adding a loop for every element
#
# Iterating through half a collection is still O(n)
#
# Two separate collections: O(a * b)
#
# What Can Cause Time in a Function?
# Operations (+, -, *, /)
# Comparisons (<, >, ==)
# Looping (for, while)
# Outside Function call (function())
#
# Rule Book
# Rule 1: Always worst Case
# Rule 2: Remove Constants
# Rule 3:
# • Different inputs should have different variables: O(a + b)
# • A and B arrays nested would be: O(a * b)
# + for steps in order
# * for nested steps
# Rule 4: Drop Non-dominant terms
#
# What Causes Space Complexity?
# • Variables
# • Data Structures
# • Function Call
# • Allocations

# %% [markdown]
# # Big O complexity
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Best to Worst

# O(1)
# O(log n)
# O(n)
# O(n log n)
# O(n^2)
# O(2^n)
# O(n!)

# Rules for Big O calculation
# Rule 1 : Worst Case
# Rule 2 : Remove Constants
# Rule 3 : Different Terms for inputs
# Rule 4 : Drop non dominants

# %% [markdown]
# ### O(n) > Linear Time
# ### O(1) > Constatnt Time
# ### O(n^2) > Quadratic Time

# %%
# Rule 3 : Differnet terms of inputs

def CompressBoxTwice(boxes,boxes2):
    for i in boxes:  # O(m)
        print(i)
    for j in boxes2:  # O(n)
        print(j)
        
        
# Big O = O(m + n)

# %%
# Nested Loops O(n^2)

sampleset = [1,2,3,4,5]

for i in sampleset: # O(n)
    for j in sampleset: # O(n)
        print(str(i) + "," + str(j))
        
        
# For nested loops we use multiplication
# O(n) * O(n) = O(n^2)
# Out:
# 1,1
# 1,2
# 1,3
# 1,4
# 1,5
# 2,1
# 2,2
# 2,3
# 2,4
# 2,5
# 3,1
# 3,2
# 3,3
# 3,4
# 3,5
# 4,1
# 4,2
# 4,3
# 4,4
# 4,5
# 5,1
# 5,2
# 5,3
# 5,4
# 5,5

# %%
# Rule no 4 : Drop the non dominant

# O(n + n^2) = O(n^2)
# O(n) is less domminant than O(n^2) so dropping O(n)

# %% [markdown]
# ## Space complexity

# %%
# Heap - (Variables)
# Stack - (Function calls)

# What causes Space Complexity ? 
# 1) Variables
# 2) Data Structues
# 3) Function Call
# 4) Allocations

# %%
# Notes : 

# Variable input space is not considered
list = ["A","B","C"]
list2 = ["C","D"]

for i in list2:
    if str(list).__contains__(i):
        print('contains '+i)
        break
    else:
        print('Loop for '+i)
        pass
# Out:
# contains C
